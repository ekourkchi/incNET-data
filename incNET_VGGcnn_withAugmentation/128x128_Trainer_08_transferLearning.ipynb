# %% [markdown]
# # Transfer Learning
#
# ## Using the VGG16 [ImageNet](https://www.image-net.org/) weights to retrain a model
#
# In this notebook, we adopt the structure and weight number of the **VGG16** convolutional neural network pretrained using the *ImageNET* sample. The last two fully connected layers are removed and replace by a set of fresh fully connected layers.
#
# - We freeze all the weight number of the original VGG16 network and only let the fully connected section to participate in the training process.
#
# - VGG16 takes 224x224 images as input. We have already generated the augmented sample of 128x128 galaxies, and therefore we need to add extra zero padding around our sample images to make them compatible with the VGG16 structure. Another approach might be to prepare another sample of 224x224 images from our original 512x512 galaxy images, however we don't pursue that approach here.

# %% [markdown]
# ![VGG16 Architecture](attachment:image.png)
# [figure source](https://neurohive.io/en/popular-networks/vgg16/)

# %% [markdown]
# ## Importing packages

# %%
import sys, os, gc
import subprocess
from math import *
import numpy as np
from datetime import *
from pylab import *
import random
from datetime import datetime
import json
import imgaug as ia
import imgaug.augmenters as iaa
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ## Importing the VGG16 model
#
# The VGG16 model comprises of 16 convolutional layers divided into 4 sections, each of which has 3 convolutional and 1 Max pooling layer. The convolution filters are of shape 3x3.

# %% [markdown]
# ![VGG16](attachment:image.png)
# [figure source](https://neurohive.io/en/popular-networks/vgg16/)

# %%
from tensorflow.keras.applications import vgg16
from tensorflow.keras import applications
from tensorflow.keras.models import Model

# %%
MODEL = applications.vgg16.VGG16(include_top=True, weights='imagenet')

## we fix the weight values of all layers, as we don't tend to train the convolutional part
MODEL.trainable = False

import pandas as pd
layers = [(layer, layer.name, layer.trainable) for layer in MODEL.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
#                                            Layer Type    Layer Name  \
# 0   <tensorflow.python.keras.engine.input_layer.In...       input_6
# 1   <tensorflow.python.keras.layers.convolutional....  block1_conv1
# 2   <tensorflow.python.keras.layers.convolutional....  block1_conv2
# 3   <tensorflow.python.keras.layers.pooling.MaxPoo...   block1_pool
# 4   <tensorflow.python.keras.layers.convolutional....  block2_conv1
# 5   <tensorflow.python.keras.layers.convolutional....  block2_conv2
# 6   <tensorflow.python.keras.layers.pooling.MaxPoo...   block2_pool
# 7   <tensorflow.python.keras.layers.convolutional....  block3_conv1
# 8   <tensorflow.python.keras.layers.convolutional....  block3_conv2
# 9   <tensorflow.python.keras.layers.convolutional....  block3_conv3
# 10  <tensorflow.python.keras.layers.pooling.MaxPoo...   block3_pool
# 11  <tensorflow.python.keras.layers.convolutional....  block4_conv1
# 12  <tensorflow.python.keras.layers.convolutional....  block4_conv2
# 13  <tensorflow.python.keras.layers.convolutional....  block4_conv3
# 14  <tensorflow.python.keras.layers.pooling.MaxPoo...   block4_pool
# 15  <tensorflow.python.keras.layers.convolutional....  block5_conv1
# 16  <tensorflow.python.keras.layers.convolutional....  block5_conv2
# 17  <tensorflow.python.keras.layers.convolutional....  block5_conv3
# 18  <tensorflow.python.keras.layers.pooling.MaxPoo...   block5_pool
# 19  <tensorflow.python.keras.layers.core.Flatten o...       flatten
# 20  <tensorflow.python.keras.layers.core.Dense obj...           fc1
# 21  <tensorflow.python.keras.layers.core.Dense obj...           fc2
# 22  <tensorflow.python.keras.layers.core.Dense obj...   predictions
#
#     Layer Trainable
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# 5             False
# 6             False
# 7             False
# 8             False
# 9             False
# 10            False
# 11            False
# 12            False
# 13            False
# 14            False
# 15            False
# 16            False
# 17            False
# 18            False
# 19            False
# 20            False
# 21            False
# 22            False

# %% [markdown]
# ## Examining the imported VGG16 model
#
# We exclude the last 4 fully connected layers.

# %%
model = Sequential()
for layer in MODEL.layers[:-4]: # the laste 4 fully connected layers from copying
    model.add(layer)
    
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ## Model definition
#
# Here, we officially construct our model. The convolutional part is exactly the same as what we have in VGG16 and all convolutional weights are not trainable. The fully connected layers are customized for our problem and all its weights are adjustable in the training process.
#
# Since we are just dealing with galaxies which are different than the [ImageNet](https://www.image-net.org/) sample, in shape and structure, we use a simpler fully connected layers with less number of trainable parameters.

# %%
def vgg():

    MODEL = applications.vgg16.VGG16(include_top=True, weights='imagenet')
    MODEL.trainable = False
    
    # Adding the convolutional layers of VGG16 layer by layer
    model = Sequential()
    for layer in MODEL.layers[:-4]: # just exclude last layer from copying
        model.add(layer)

    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(32, activation='relu'))

    model.add(Dense(8, activation='relu'))

    # output layer
    model.add(tf.keras.layers.Dense(1, activation='tanh', name='fc_out2'))

    return model

def esn_shuffle(array, seed=0):
        np.random.seed(seed)
        np.random.shuffle(array)
        return array

class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        else:
            return super(NpEncoder, self).default(obj)

# %% [markdown]
# ## The summary of our customized model

# %%
model = vgg()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               3211392
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 264
# _________________________________________________________________
# fc_out2 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 17,930,481
# Trainable params: 3,215,793
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ### A customized shuffling function to randomize the input arrays

# %%
def esn_shuffle(array, seed=None):
        if seed is not None:
            np.random.seed(seed)
        np.random.shuffle(array)
        return array

# %% [markdown]
# ### Augmentations for the test images

# %%
seq = iaa.Sequential([
    iaa.Sometimes(0.5, iaa.GaussianBlur(sigma=(0, 0.1))),
    iaa.GammaContrast(gamma=(0.97,1.03)),
    iaa.AdditiveGaussianNoise(loc=0, scale=(0.0, 3), per_channel=0.5),
    iaa.Add((-5, 5), per_channel=0.5),
    iaa.Multiply((0.8, 1.2), per_channel=0.5),
    iaa.Sometimes(0.1, iaa.Grayscale(alpha=(0.0, 1.0))),
    iaa.Sometimes(0.50, iaa.Grayscale(alpha=1.)),
    iaa.Fliplr(0.5),
    iaa.Flipud(0.5),
    iaa.Affine(
        rotate=(0, 359),
        scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
        translate_percent={"x": (-0.15, 0.15), "y": (-0.15, 0.15)}, 
        mode=ia.ALL, cval=(0, 255))
    ], random_order=True)


seqGray = iaa.Sequential([
    iaa.GammaContrast(gamma=(0.97,1.03)),
    iaa.Fliplr(0.5),
    iaa.Flipud(0.5),
    iaa.Affine(
        rotate=(0, 359),
        scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
        translate_percent={"x": (-0.15, 0.15), "y": (-0.15, 0.15)}, 
        mode=ia.ALL, cval=(255, 255))
    ], random_order=True)

# %% [markdown]
# ### Importing text images
#
# `samples/<filter>_128x128_test_000.npz` have not been already augmented. Therefore we augment them in the same way we prepared the training sample.

# %%
# %%time 

data = np.load('samples/RGB_128x128_test_000.npz')
images_RGB = data['images'].astype(np.uint8)
labels_RGB = data['labels'] 
pgcIDs_RGB = data['pgcIDs']
N = images_RGB.shape[0]
filter_RGB = np.chararray(N)
filter_RGB[:] = 'c'
data.close() 
del data


data = np.load('samples/g_128x128_test_000.npz')
images_g = data['images'].astype(np.uint8)
labels_g = data['labels'] 
pgcIDs_g = data['pgcIDs']
N = images_g.shape[0]
filter_g = np.chararray(N)
filter_g[:] = 'g'
data.close() 
del data

data = np.load('samples/r_128x128_test_000.npz')
images_r = data['images'].astype(np.uint8)
labels_r = data['labels'] 
pgcIDs_r = data['pgcIDs']
N = images_r.shape[0]
filter_r = np.chararray(N)
filter_r[:] = 'r'
data.close() 
del data

data = np.load('samples/i_128x128_test_000.npz')
images_i = data['images'].astype(np.uint8)
labels_i = data['labels'] 
pgcIDs_i = data['pgcIDs']
N = images_i.shape[0]
filter_i = np.chararray(N)
filter_i[:] = 'i'
data.close() 
del data
# Out:
# CPU times: user 2.43 s, sys: 386 ms, total: 2.81 s
# Wall time: 3.82 s

# %% [markdown]
# ### Concatenating the gray test images taken at g, r, and i bands

# %%
images_gri = np.concatenate((images_g, images_r, images_i))
labels_gri = np.concatenate((labels_g, labels_r, labels_i))
pgcIDs_gri = np.concatenate((pgcIDs_g, pgcIDs_r, pgcIDs_i))
filter_gri = np.concatenate((filter_g, filter_r, filter_i))

N_RGB = len(labels_RGB)
N_gri = len(labels_gri)

# %% [markdown]
# Here, we shuffle `gri` images and then we randomly invert half of them. In this way half of the galaxy images have black background and the other half have white background.

# %%
ia.seed(100)

indx = esn_shuffle(np.arange(N_gri), seed=200)
images_aug = seqGray(images=images_gri[indx][:N_RGB,:,:,:])
labels_aug = labels_gri[indx][:N_RGB]
pgcIDs_aug = pgcIDs_gri[indx][:N_RGB]
filter_aug = filter_gri[indx][:N_RGB]

n = len(images_aug)
p = int(n/2)
images_aug[:p] = 255 - images_aug[:p]

ia.seed(200)

images_aug = np.concatenate((seq(images=images_RGB),images_aug))
labels_aug = np.concatenate((labels_RGB,labels_aug))
pgcIDs_aug = np.concatenate((pgcIDs_RGB,pgcIDs_aug))
filter_aug = np.concatenate((filter_RGB,filter_aug))

indx = np.arange(len(images_aug))
indx = esn_shuffle(indx, seed=100)
images_test_aug = images_aug[indx]
labels_test_aug = labels_aug[indx]
pgcIDs_test_aug = pgcIDs_aug[indx]
filter_test_aug = filter_aug[indx]

# inclinations are mapped to range between -1 and 1, compatibale with the tanh outputs
labels_test_aug = 2.*(labels_test_aug-45.)/45. - 1.

# %% [markdown]
# The resolution of images in our sample is 128x128. So we add extra zero padding around images to enlarge them into 224x224.

# %%
images_test_aug.shape
# Out:
# (3314, 128, 128, 3)

# %% [markdown]
# ## An example of a padded image

# %%
N, _, _, _ = images_test_aug.shape
images_224x224 = np.zeros((N, 224, 224, 3), dtype=np.dtype('>i4'))
images_224x224[:,48:176,48:176, :] = images_test_aug
images_test_aug = images_224x224
del images_224x224

plt.imshow(images_test_aug[30])

# %% [markdown]
# ### Batch number generation
#
# We have 50 batches of training data, each stored in a separate `npz` file on the disk.
# Each grand Epoch includes all 50 random iterations that cover the entire training sample. Within each epoch, batches are fed to the network in different orders.
# Below, we generate 60 grand epochs of 50 small iterations. Each iteration covers one training sub-sample in `npz` format.

# %%
batches = esn_shuffle(np.arange(50), seed=20)

for i in range(1,60):
    batches = np.concatenate((batches, esn_shuffle(np.arange(50), seed=i*20))) 

batches, len(batches)
# Out:
# (array([12, 14,  4, ..., 14, 15, 45]), 3000)

# %% [markdown]
# ## Training Process
#
# - *zp_dir:* Folder that contains all 50 training batches in `npz` format
# - *ckpt_dir:* Folder to save the weight numbers of the network after each iteration
#
#
# Advancing the training process at each step consists of
#
# 1.  Reconstruction of the model as it is at the end of the previous step
# 2.  Reading the `npz` file that holds the corresponding batch
# 3.  Training the model for one epoch (moving forward just for 1 iteration)
# 4.  Updating the JSON file that contains the desired network metrics
# 5.  Saving the weight values of the model for the use in the next iteration

# %%
zp_dir = 'Uset0_npz/'
ckpt_dir = 'U0_model08_ckpt/'

def trainer(iter, batches, suffix=None):

  if suffix is None:
    suffix = ''

  batchNo = batches[iter]
  if True: 
    
    ## initializing the model in the beginning of each iteration
    vgg_model = vgg()
    vgg_model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(), metrics=['mse', 'mae'])

    if iter>0:
      
      vgg_model = vgg()
      vgg_model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(), metrics=['mse', 'mae'])
    
      ## if we are in  the middle of the training process, we load the weight number of the network 
      ## produced in the previous step
      vgg_model.load_weights(ckpt_dir+str(iter-1)+suffix+".ckpt")

      ## The networks performance metrics are stored in JSON and is updated at each step
      with open(ckpt_dir+'evalDict'+suffix+'.json') as json_file:
        evalDict = json.load(json_file)
    else:
      evalDict = {}


    print("iter #{}".format(iter))
    print("Batch number: {}".format(batchNo))

    
    # reading out the training batch from disk
    batchFile = npzname = '128x128_train_aug_'+'%02d'%(batchNo+1)+'.npz'
    data = np.load(zp_dir + batchFile)
#     images_train_aug = data['images'].astype(np.uint8)
    
#     N, _, _, _ = images_train_aug.shape
#     print(images_train_aug.shape)
    images_train_aug = np.zeros((10000, 224, 224, 3), dtype=np.dtype('>i4'))
    images_train_aug[:,48:176,48:176, :] = data['images'].astype(np.uint8)[:10000]
#     images_train_aug = images_224x224
#     del images_224x224

    labels_train_aug = data['labels']
    pgcIDs_train_aug = data['pgcIDs']
    data.close() 
    del data
    
    # mapping out the labels to lie between -1 and 1
    labels_train_aug = 2.*(labels_train_aug-45.)/45. - 1.
    
    n_epochs=1
    vgg_model.fit(images_train_aug, labels_train_aug[:10000], 
                                      epochs=n_epochs, batch_size=128, 
                                      validation_data=(images_test_aug, labels_test_aug),
                                      verbose=1, shuffle=True)
    
    # updating the JSON file that holds all metrics
    evalDict[iter] = {} 
    for key in vgg_model.history.history:
      evalDict[iter][key] = vgg_model.history.history[key][0]
    evalDict[iter]["batchNo"] = batchNo
    evalDict[iter]["batchFile"] = batchFile
    
    with open(ckpt_dir+"evalDict"+suffix+".json", "w", encoding ='utf8') as outfile:
      json.dump(evalDict, outfile, allow_nan=True, cls=NpEncoder)
    
    
    ## Taking an snapshot of the network to be used in the proceeding iteration
    vgg_model.save_weights(ckpt_dir+str(iter)+suffix+".ckpt")

    del vgg_model
    tf.keras.backend.clear_session()
    del images_train_aug 
    del labels_train_aug
    del pgcIDs_train_aug

    gc.collect()

    return evalDict

# %% [markdown]
# ### Training the network until no further improvements can be achieved
#
# or until achieving convergence.
#
# If the training process doesn't improve the evaluations metrics on the test (evaluation) set, we stop the training process.

# %%
with tf.device('/gpu:0'):
    for i in range(0, 500):
        trainer(i, batches)
# Out:
# iter #310
# Batch number: 12
# 79/79 [==============================] - 91s 885ms/step - loss: 0.0413 - mse: 0.0413 - mae: 0.1527 - val_loss: 0.0567 - val_mse: 0.0567 - val_mae: 0.1701
# iter #311
# Batch number: 21
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0421 - mse: 0.0421 - mae: 0.1550 - val_loss: 0.0569 - val_mse: 0.0569 - val_mae: 0.1701
# iter #312
# Batch number: 32
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0411 - mse: 0.0411 - mae: 0.1515 - val_loss: 0.0548 - val_mse: 0.0548 - val_mae: 0.1687
# iter #313
# Batch number: 5
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0409 - mse: 0.0409 - mae: 0.1504 - val_loss: 0.0566 - val_mse: 0.0566 - val_mae: 0.1697
# iter #314
# Batch number: 27
# 79/79 [==============================] - 52s 658ms/step - loss: 0.0431 - mse: 0.0431 - mae: 0.1547 - val_loss: 0.0593 - val_mse: 0.0593 - val_mae: 0.1789
# iter #315
# Batch number: 49
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0412 - mse: 0.0412 - mae: 0.1516 - val_loss: 0.0626 - val_mse: 0.0626 - val_mae: 0.1835
# iter #316
# Batch number: 35
# 79/79 [==============================] - 51s 641ms/step - loss: 0.0403 - mse: 0.0403 - mae: 0.1508 - val_loss: 0.0579 - val_mse: 0.0579 - val_mae: 0.1739
# iter #317
# Batch number: 1
# 79/79 [==============================] - 52s 648ms/step - loss: 0.0416 - mse: 0.0416 - mae: 0.1540 - val_loss: 0.0567 - val_mse: 0.0567 - val_mae: 0.1702
# iter #318
# Batch number: 6
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0416 - mse: 0.0416 - mae: 0.1526 - val_loss: 0.0559 - val_mse: 0.0559 - val_mae: 0.1703
# iter #319
# Batch number: 8
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0449 - mse: 0.0449 - mae: 0.1569 - val_loss: 0.0608 - val_mse: 0.0608 - val_mae: 0.1750
# iter #320
# Batch number: 22
# 79/79 [==============================] - 52s 654ms/step - loss: 0.0427 - mse: 0.0427 - mae: 0.1551 - val_loss: 0.0592 - val_mse: 0.0592 - val_mae: 0.1755
# iter #321
# Batch number: 46
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0415 - mse: 0.0415 - mae: 0.1525 - val_loss: 0.0539 - val_mse: 0.0539 - val_mae: 0.1678
# iter #322
# Batch number: 28
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0414 - mse: 0.0414 - mae: 0.1513 - val_loss: 0.0549 - val_mse: 0.0549 - val_mae: 0.1683
# iter #323
# Batch number: 34
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0410 - mse: 0.0410 - mae: 0.1528 - val_loss: 0.0609 - val_mse: 0.0609 - val_mae: 0.1735
# iter #324
# Batch number: 43
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0409 - mse: 0.0409 - mae: 0.1519 - val_loss: 0.0557 - val_mse: 0.0557 - val_mae: 0.1679
# iter #325
# Batch number: 15
# 79/79 [==============================] - 52s 656ms/step - loss: 0.0416 - mse: 0.0416 - mae: 0.1530 - val_loss: 0.0609 - val_mse: 0.0609 - val_mae: 0.1760
# iter #326
# Batch number: 16
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0429 - mse: 0.0429 - mae: 0.1555 - val_loss: 0.0535 - val_mse: 0.0535 - val_mae: 0.1660
# iter #327
# Batch number: 48
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0403 - mse: 0.0403 - mae: 0.1511 - val_loss: 0.0652 - val_mse: 0.0652 - val_mae: 0.1852
# iter #328
# Batch number: 29
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0419 - mse: 0.0419 - mae: 0.1538 - val_loss: 0.0551 - val_mse: 0.0551 - val_mae: 0.1668
# iter #329
# Batch number: 2
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0432 - mse: 0.0432 - mae: 0.1548 - val_loss: 0.0550 - val_mse: 0.0550 - val_mae: 0.1699
# iter #330
# Batch number: 18
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0430 - mse: 0.0430 - mae: 0.1541 - val_loss: 0.0561 - val_mse: 0.0561 - val_mae: 0.1714
# iter #331
# Batch number: 36
# 79/79 [==============================] - 53s 668ms/step - loss: 0.0420 - mse: 0.0420 - mae: 0.1545 - val_loss: 0.0601 - val_mse: 0.0601 - val_mae: 0.1741
# iter #332
# Batch number: 7
# 79/79 [==============================] - 53s 664ms/step - loss: 0.0437 - mse: 0.0437 - mae: 0.1555 - val_loss: 0.0567 - val_mse: 0.0567 - val_mae: 0.1698
# iter #333
# Batch number: 4
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0429 - mse: 0.0429 - mae: 0.1562 - val_loss: 0.0601 - val_mse: 0.0601 - val_mae: 0.1748
# iter #334
# Batch number: 42
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0422 - mse: 0.0422 - mae: 0.1538 - val_loss: 0.0586 - val_mse: 0.0586 - val_mae: 0.1713
# iter #335
# Batch number: 25
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0448 - mse: 0.0448 - mae: 0.1588 - val_loss: 0.0602 - val_mse: 0.0602 - val_mae: 0.1776
# iter #336
# Batch number: 13
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0428 - mse: 0.0428 - mae: 0.1544 - val_loss: 0.0581 - val_mse: 0.0581 - val_mae: 0.1738
# iter #337
# Batch number: 14
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0422 - mse: 0.0422 - mae: 0.1519 - val_loss: 0.0618 - val_mse: 0.0618 - val_mae: 0.1781
# iter #338
# Batch number: 38
# 79/79 [==============================] - 52s 653ms/step - loss: 0.0410 - mse: 0.0410 - mae: 0.1526 - val_loss: 0.0678 - val_mse: 0.0678 - val_mae: 0.1901
# iter #339
# Batch number: 44
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0458 - mse: 0.0458 - mae: 0.1604 - val_loss: 0.0578 - val_mse: 0.0578 - val_mae: 0.1740
# iter #340
# Batch number: 24
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0441 - mse: 0.0441 - mae: 0.1573 - val_loss: 0.0581 - val_mse: 0.0581 - val_mae: 0.1736
# iter #341
# Batch number: 19
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0397 - mse: 0.0397 - mae: 0.1509 - val_loss: 0.0601 - val_mse: 0.0601 - val_mae: 0.1790
# iter #342
# Batch number: 33
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0432 - mse: 0.0432 - mae: 0.1550 - val_loss: 0.0578 - val_mse: 0.0578 - val_mae: 0.1702
# iter #343
# Batch number: 23
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0417 - mse: 0.0417 - mae: 0.1532 - val_loss: 0.0550 - val_mse: 0.0550 - val_mae: 0.1678
# iter #344
# Batch number: 20
# 79/79 [==============================] - 52s 654ms/step - loss: 0.0428 - mse: 0.0428 - mae: 0.1523 - val_loss: 0.0563 - val_mse: 0.0563 - val_mae: 0.1672
# iter #345
# Batch number: 10
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0425 - mse: 0.0425 - mae: 0.1538 - val_loss: 0.0544 - val_mse: 0.0544 - val_mae: 0.1672
# iter #346
# Batch number: 31
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0420 - mse: 0.0420 - mae: 0.1525 - val_loss: 0.0601 - val_mse: 0.0601 - val_mae: 0.1768
# iter #347
# Batch number: 30
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0444 - mse: 0.0444 - mae: 0.1576 - val_loss: 0.0566 - val_mse: 0.0566 - val_mae: 0.1682
# iter #348
# Batch number: 0
# 79/79 [==============================] - 51s 645ms/step - loss: 0.0442 - mse: 0.0442 - mae: 0.1573 - val_loss: 0.0617 - val_mse: 0.0617 - val_mae: 0.1799
# iter #349
# Batch number: 39
# 79/79 [==============================] - 51s 645ms/step - loss: 0.0410 - mse: 0.0410 - mae: 0.1539 - val_loss: 0.0559 - val_mse: 0.0559 - val_mae: 0.1678
# iter #350
# Batch number: 27
# 79/79 [==============================] - 53s 659ms/step - loss: 0.0402 - mse: 0.0402 - mae: 0.1510 - val_loss: 0.0561 - val_mse: 0.0561 - val_mae: 0.1684
# iter #351
# Batch number: 9
# 79/79 [==============================] - 51s 646ms/step - loss: 0.0414 - mse: 0.0414 - mae: 0.1524 - val_loss: 0.0568 - val_mse: 0.0568 - val_mae: 0.1680
# iter #352
# Batch number: 6
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0406 - mse: 0.0406 - mae: 0.1514 - val_loss: 0.0622 - val_mse: 0.0622 - val_mae: 0.1820
# iter #353
# Batch number: 24
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0376 - mse: 0.0376 - mae: 0.1463 - val_loss: 0.0599 - val_mse: 0.0599 - val_mae: 0.1747
# iter #354
# Batch number: 33
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1477 - val_loss: 0.0589 - val_mse: 0.0589 - val_mae: 0.1707
# iter #355
# Batch number: 41
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0403 - mse: 0.0403 - mae: 0.1498 - val_loss: 0.0571 - val_mse: 0.0571 - val_mae: 0.1713
# iter #356
# Batch number: 14
# 79/79 [==============================] - 55s 688ms/step - loss: 0.0359 - mse: 0.0359 - mae: 0.1440 - val_loss: 0.0576 - val_mse: 0.0576 - val_mae: 0.1692
# iter #357
# Batch number: 30
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0373 - mse: 0.0373 - mae: 0.1458 - val_loss: 0.0659 - val_mse: 0.0659 - val_mae: 0.1800
# iter #358
# Batch number: 48
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1505 - val_loss: 0.0609 - val_mse: 0.0609 - val_mae: 0.1758
# iter #359
# Batch number: 29
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0383 - mse: 0.0383 - mae: 0.1479 - val_loss: 0.0589 - val_mse: 0.0589 - val_mae: 0.1730
# iter #360
# Batch number: 46
# 79/79 [==============================] - 53s 671ms/step - loss: 0.0377 - mse: 0.0377 - mae: 0.1469 - val_loss: 0.0599 - val_mse: 0.0599 - val_mae: 0.1724
# iter #361
# Batch number: 19
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0369 - mse: 0.0369 - mae: 0.1454 - val_loss: 0.0582 - val_mse: 0.0582 - val_mae: 0.1705
# iter #362
# Batch number: 25
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0382 - mse: 0.0382 - mae: 0.1477 - val_loss: 0.0605 - val_mse: 0.0605 - val_mae: 0.1729
# iter #363
# Batch number: 10
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0381 - mse: 0.0381 - mae: 0.1456 - val_loss: 0.0625 - val_mse: 0.0625 - val_mae: 0.1773
# iter #364
# Batch number: 49
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0403 - mse: 0.0403 - mae: 0.1508 - val_loss: 0.0594 - val_mse: 0.0594 - val_mae: 0.1736
# iter #365
# Batch number: 34
# 79/79 [==============================] - 53s 662ms/step - loss: 0.0384 - mse: 0.0384 - mae: 0.1476 - val_loss: 0.0650 - val_mse: 0.0650 - val_mae: 0.1838
# iter #366
# Batch number: 37
# 79/79 [==============================] - 52s 646ms/step - loss: 0.0413 - mse: 0.0413 - mae: 0.1527 - val_loss: 0.0600 - val_mse: 0.0600 - val_mae: 0.1761
# iter #367
# Batch number: 3
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0405 - mse: 0.0405 - mae: 0.1506 - val_loss: 0.0627 - val_mse: 0.0627 - val_mae: 0.1796
# iter #368
# Batch number: 1
# 79/79 [==============================] - 53s 670ms/step - loss: 0.0386 - mse: 0.0386 - mae: 0.1485 - val_loss: 0.0586 - val_mse: 0.0586 - val_mae: 0.1728
# iter #369
# Batch number: 43
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0396 - mse: 0.0396 - mae: 0.1495 - val_loss: 0.0673 - val_mse: 0.0673 - val_mae: 0.1866
# iter #370
# Batch number: 8
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0439 - mse: 0.0439 - mae: 0.1549 - val_loss: 0.0639 - val_mse: 0.0639 - val_mae: 0.1808
# iter #371
# Batch number: 47
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0410 - mse: 0.0410 - mae: 0.1510 - val_loss: 0.0619 - val_mse: 0.0619 - val_mae: 0.1780
# iter #372
# Batch number: 26
# 79/79 [==============================] - 53s 666ms/step - loss: 0.0405 - mse: 0.0405 - mae: 0.1505 - val_loss: 0.0581 - val_mse: 0.0581 - val_mae: 0.1718
# iter #373
# Batch number: 4
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0422 - mse: 0.0422 - mae: 0.1536 - val_loss: 0.0629 - val_mse: 0.0629 - val_mae: 0.1777
# iter #374
# Batch number: 7
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0388 - mse: 0.0388 - mae: 0.1472 - val_loss: 0.0555 - val_mse: 0.0555 - val_mae: 0.1674
# iter #375
# Batch number: 17
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0396 - mse: 0.0396 - mae: 0.1500 - val_loss: 0.0606 - val_mse: 0.0606 - val_mae: 0.1741
# iter #376
# Batch number: 42
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0391 - mse: 0.0391 - mae: 0.1494 - val_loss: 0.0570 - val_mse: 0.0570 - val_mae: 0.1696
# iter #377
# Batch number: 11
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0429 - mse: 0.0429 - mae: 0.1548 - val_loss: 0.0640 - val_mse: 0.0640 - val_mae: 0.1806
# iter #378
# Batch number: 2
# 79/79 [==============================] - 53s 664ms/step - loss: 0.0417 - mse: 0.0417 - mae: 0.1531 - val_loss: 0.0593 - val_mse: 0.0593 - val_mae: 0.1723
# iter #379
# Batch number: 15
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0402 - mse: 0.0402 - mae: 0.1505 - val_loss: 0.0602 - val_mse: 0.0602 - val_mae: 0.1731
# iter #380
# Batch number: 44
# 79/79 [==============================] - 52s 653ms/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1483 - val_loss: 0.0559 - val_mse: 0.0559 - val_mae: 0.1678
# iter #381
# Batch number: 12
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0417 - mse: 0.0417 - mae: 0.1520 - val_loss: 0.0572 - val_mse: 0.0572 - val_mae: 0.1693
# iter #382
# Batch number: 45
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0398 - mse: 0.0398 - mae: 0.1499 - val_loss: 0.0569 - val_mse: 0.0569 - val_mae: 0.1698
# iter #383
# Batch number: 28
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0417 - mse: 0.0417 - mae: 0.1517 - val_loss: 0.0549 - val_mse: 0.0549 - val_mae: 0.1667
# iter #384
# Batch number: 0
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0425 - mse: 0.0425 - mae: 0.1552 - val_loss: 0.0629 - val_mse: 0.0629 - val_mae: 0.1794
# iter #385
# Batch number: 5
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0403 - mse: 0.0403 - mae: 0.1502 - val_loss: 0.0568 - val_mse: 0.0568 - val_mae: 0.1688
# iter #386
# Batch number: 36
# 79/79 [==============================] - 51s 645ms/step - loss: 0.0412 - mse: 0.0412 - mae: 0.1504 - val_loss: 0.0549 - val_mse: 0.0549 - val_mae: 0.1678
# iter #387
# Batch number: 20
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0411 - mse: 0.0411 - mae: 0.1512 - val_loss: 0.0592 - val_mse: 0.0592 - val_mae: 0.1739
# iter #388
# Batch number: 31
# 79/79 [==============================] - 53s 667ms/step - loss: 0.0377 - mse: 0.0377 - mae: 0.1464 - val_loss: 0.0611 - val_mse: 0.0611 - val_mae: 0.1728
# iter #389
# Batch number: 18
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0411 - mse: 0.0411 - mae: 0.1511 - val_loss: 0.0604 - val_mse: 0.0604 - val_mae: 0.1752
# iter #390
# Batch number: 21
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0403 - mse: 0.0403 - mae: 0.1516 - val_loss: 0.0569 - val_mse: 0.0569 - val_mae: 0.1744
# iter #391
# Batch number: 39
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0378 - mse: 0.0378 - mae: 0.1483 - val_loss: 0.0555 - val_mse: 0.0555 - val_mae: 0.1673
# iter #392
# Batch number: 35
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0400 - mse: 0.0400 - mae: 0.1501 - val_loss: 0.0572 - val_mse: 0.0572 - val_mae: 0.1715
# iter #393
# Batch number: 32
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0405 - mse: 0.0405 - mae: 0.1507 - val_loss: 0.0617 - val_mse: 0.0617 - val_mae: 0.1771
# iter #394
# Batch number: 16
# 79/79 [==============================] - 53s 664ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1495 - val_loss: 0.0620 - val_mse: 0.0620 - val_mae: 0.1785
# iter #395
# Batch number: 13
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0420 - mse: 0.0420 - mae: 0.1527 - val_loss: 0.0583 - val_mse: 0.0583 - val_mae: 0.1740
# iter #396
# Batch number: 22
# 79/79 [==============================] - 54s 683ms/step - loss: 0.0426 - mse: 0.0426 - mae: 0.1538 - val_loss: 0.0624 - val_mse: 0.0624 - val_mae: 0.1775
# iter #397
# Batch number: 23
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0375 - mse: 0.0375 - mae: 0.1456 - val_loss: 0.0540 - val_mse: 0.0540 - val_mae: 0.1662
# iter #398
# Batch number: 38
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0397 - mse: 0.0397 - mae: 0.1507 - val_loss: 0.0586 - val_mse: 0.0586 - val_mae: 0.1719
# iter #399
# Batch number: 40
# 79/79 [==============================] - 52s 647ms/step - loss: 0.0417 - mse: 0.0417 - mae: 0.1516 - val_loss: 0.0559 - val_mse: 0.0559 - val_mae: 0.1680
# iter #400
# Batch number: 39
# 79/79 [==============================] - 51s 645ms/step - loss: 0.0342 - mse: 0.0342 - mae: 0.1416 - val_loss: 0.0606 - val_mse: 0.0606 - val_mae: 0.1743
# iter #401
# Batch number: 43
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0376 - mse: 0.0376 - mae: 0.1455 - val_loss: 0.0605 - val_mse: 0.0605 - val_mae: 0.1761
# iter #402
# Batch number: 37
# 79/79 [==============================] - 53s 670ms/step - loss: 0.0367 - mse: 0.0367 - mae: 0.1441 - val_loss: 0.0657 - val_mse: 0.0657 - val_mae: 0.1807
# iter #403
# Batch number: 10
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0396 - mse: 0.0396 - mae: 0.1486 - val_loss: 0.0607 - val_mse: 0.0607 - val_mae: 0.1772
# iter #404
# Batch number: 13
# 79/79 [==============================] - 51s 645ms/step - loss: 0.0372 - mse: 0.0372 - mae: 0.1457 - val_loss: 0.0612 - val_mse: 0.0612 - val_mae: 0.1748
# iter #405
# Batch number: 41
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1482 - val_loss: 0.0729 - val_mse: 0.0729 - val_mae: 0.1964
# iter #406
# Batch number: 22
# 79/79 [==============================] - 51s 645ms/step - loss: 0.0395 - mse: 0.0395 - mae: 0.1491 - val_loss: 0.0565 - val_mse: 0.0565 - val_mae: 0.1700
# iter #407
# Batch number: 24
# 79/79 [==============================] - 51s 645ms/step - loss: 0.0389 - mse: 0.0389 - mae: 0.1474 - val_loss: 0.0564 - val_mse: 0.0564 - val_mae: 0.1678
# iter #408
# Batch number: 42
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0368 - mse: 0.0368 - mae: 0.1449 - val_loss: 0.0665 - val_mse: 0.0665 - val_mae: 0.1849
# iter #409
# Batch number: 0
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0371 - mse: 0.0371 - mae: 0.1465 - val_loss: 0.0585 - val_mse: 0.0585 - val_mae: 0.1760
# iter #410
# Batch number: 46
# 79/79 [==============================] - 52s 646ms/step - loss: 0.0380 - mse: 0.0380 - mae: 0.1476 - val_loss: 0.0592 - val_mse: 0.0592 - val_mae: 0.1751
# iter #411
# Batch number: 33
# 79/79 [==============================] - 53s 670ms/step - loss: 0.0375 - mse: 0.0375 - mae: 0.1455 - val_loss: 0.0620 - val_mse: 0.0620 - val_mae: 0.1748
# iter #412
# Batch number: 35
# 79/79 [==============================] - 52s 646ms/step - loss: 0.0355 - mse: 0.0355 - mae: 0.1424 - val_loss: 0.0622 - val_mse: 0.0622 - val_mae: 0.1767
# iter #413
# Batch number: 14
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0370 - mse: 0.0370 - mae: 0.1442 - val_loss: 0.0636 - val_mse: 0.0636 - val_mae: 0.1818
# iter #414
# Batch number: 48
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0384 - mse: 0.0384 - mae: 0.1456 - val_loss: 0.0638 - val_mse: 0.0638 - val_mae: 0.1819
# iter #415
# Batch number: 45
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0391 - mse: 0.0391 - mae: 0.1482 - val_loss: 0.0645 - val_mse: 0.0645 - val_mae: 0.1795
# iter #416
# Batch number: 29
# 79/79 [==============================] - 53s 669ms/step - loss: 0.0364 - mse: 0.0364 - mae: 0.1447 - val_loss: 0.0577 - val_mse: 0.0577 - val_mae: 0.1708
# iter #417
# Batch number: 9
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0396 - mse: 0.0396 - mae: 0.1502 - val_loss: 0.0597 - val_mse: 0.0597 - val_mae: 0.1742
# iter #418
# Batch number: 21
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0382 - mse: 0.0382 - mae: 0.1463 - val_loss: 0.0595 - val_mse: 0.0595 - val_mae: 0.1730
# iter #419
# Batch number: 11
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0368 - mse: 0.0368 - mae: 0.1444 - val_loss: 0.0644 - val_mse: 0.0644 - val_mae: 0.1840
# iter #420
# Batch number: 2
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0385 - mse: 0.0385 - mae: 0.1485 - val_loss: 0.0629 - val_mse: 0.0629 - val_mae: 0.1805
# iter #421
# Batch number: 6
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0383 - mse: 0.0383 - mae: 0.1459 - val_loss: 0.0599 - val_mse: 0.0599 - val_mae: 0.1731
# iter #422
# Batch number: 20
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0386 - mse: 0.0386 - mae: 0.1460 - val_loss: 0.0592 - val_mse: 0.0592 - val_mae: 0.1715
# iter #423
# Batch number: 7
# 79/79 [==============================] - 53s 669ms/step - loss: 0.0371 - mse: 0.0371 - mae: 0.1446 - val_loss: 0.0559 - val_mse: 0.0559 - val_mae: 0.1677
# iter #424
# Batch number: 44
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0388 - mse: 0.0388 - mae: 0.1467 - val_loss: 0.0574 - val_mse: 0.0574 - val_mae: 0.1702
# iter #425
# Batch number: 18
# 79/79 [==============================] - 53s 666ms/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1479 - val_loss: 0.0687 - val_mse: 0.0687 - val_mae: 0.1859
# iter #426
# Batch number: 36
# 79/79 [==============================] - 53s 667ms/step - loss: 0.0402 - mse: 0.0402 - mae: 0.1504 - val_loss: 0.0620 - val_mse: 0.0620 - val_mae: 0.1748
# iter #427
# Batch number: 32
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0383 - mse: 0.0383 - mae: 0.1447 - val_loss: 0.0597 - val_mse: 0.0597 - val_mae: 0.1737
# iter #428
# Batch number: 3
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0380 - mse: 0.0380 - mae: 0.1456 - val_loss: 0.0584 - val_mse: 0.0584 - val_mae: 0.1713
# iter #429
# Batch number: 31
# 79/79 [==============================] - 52s 645ms/step - loss: 0.0369 - mse: 0.0369 - mae: 0.1433 - val_loss: 0.0607 - val_mse: 0.0607 - val_mae: 0.1734
# iter #430
# Batch number: 30
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0371 - mse: 0.0371 - mae: 0.1449 - val_loss: 0.0561 - val_mse: 0.0561 - val_mae: 0.1679
# iter #431
# Batch number: 19
# 79/79 [==============================] - 51s 645ms/step - loss: 0.0388 - mse: 0.0388 - mae: 0.1486 - val_loss: 0.0646 - val_mse: 0.0646 - val_mae: 0.1824
# iter #432
# Batch number: 4
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0400 - mse: 0.0400 - mae: 0.1511 - val_loss: 0.0594 - val_mse: 0.0594 - val_mae: 0.1714
# iter #433
# Batch number: 23
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0370 - mse: 0.0370 - mae: 0.1450 - val_loss: 0.0560 - val_mse: 0.0560 - val_mae: 0.1680
# iter #434
# Batch number: 5
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0403 - mse: 0.0403 - mae: 0.1498 - val_loss: 0.0583 - val_mse: 0.0583 - val_mae: 0.1704
# iter #435
# Batch number: 27
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1477 - val_loss: 0.0594 - val_mse: 0.0594 - val_mae: 0.1723
# iter #436
# Batch number: 15
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0387 - mse: 0.0387 - mae: 0.1481 - val_loss: 0.0558 - val_mse: 0.0558 - val_mae: 0.1692
# iter #437
# Batch number: 38
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0388 - mse: 0.0388 - mae: 0.1481 - val_loss: 0.0583 - val_mse: 0.0583 - val_mae: 0.1711
# iter #438
# Batch number: 17
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0387 - mse: 0.0387 - mae: 0.1477 - val_loss: 0.0589 - val_mse: 0.0589 - val_mae: 0.1705
# iter #439
# Batch number: 34
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0377 - mse: 0.0377 - mae: 0.1464 - val_loss: 0.0603 - val_mse: 0.0603 - val_mae: 0.1732
# iter #440
# Batch number: 12
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0391 - mse: 0.0391 - mae: 0.1483 - val_loss: 0.0594 - val_mse: 0.0594 - val_mae: 0.1731
# iter #441
# Batch number: 25
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0388 - mse: 0.0388 - mae: 0.1488 - val_loss: 0.0550 - val_mse: 0.0550 - val_mae: 0.1669
# iter #442
# Batch number: 16
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0388 - mse: 0.0388 - mae: 0.1484 - val_loss: 0.0548 - val_mse: 0.0548 - val_mae: 0.1656
# iter #443
# Batch number: 8
# 79/79 [==============================] - 52s 654ms/step - loss: 0.0395 - mse: 0.0395 - mae: 0.1492 - val_loss: 0.0586 - val_mse: 0.0586 - val_mae: 0.1700
# iter #444
# Batch number: 28
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0386 - mse: 0.0386 - mae: 0.1471 - val_loss: 0.0558 - val_mse: 0.0558 - val_mae: 0.1674
# iter #445
# Batch number: 1
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0403 - mse: 0.0403 - mae: 0.1507 - val_loss: 0.0611 - val_mse: 0.0611 - val_mae: 0.1731
# iter #446
# Batch number: 49
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0401 - mse: 0.0401 - mae: 0.1493 - val_loss: 0.0557 - val_mse: 0.0557 - val_mae: 0.1687
# iter #447
# Batch number: 47
# 79/79 [==============================] - 53s 659ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1481 - val_loss: 0.0594 - val_mse: 0.0594 - val_mae: 0.1739
# iter #448
# Batch number: 26
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0375 - mse: 0.0375 - mae: 0.1440 - val_loss: 0.0564 - val_mse: 0.0564 - val_mae: 0.1685
# iter #449
# Batch number: 40
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0403 - mse: 0.0403 - mae: 0.1508 - val_loss: 0.0581 - val_mse: 0.0581 - val_mae: 0.1715
# iter #450
# Batch number: 40
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0291 - mse: 0.0291 - mae: 0.1301 - val_loss: 0.0560 - val_mse: 0.0560 - val_mae: 0.1677
# iter #451
# Batch number: 4
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0361 - mse: 0.0361 - mae: 0.1419 - val_loss: 0.0642 - val_mse: 0.0642 - val_mae: 0.1820
# iter #452
# Batch number: 31
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0354 - mse: 0.0354 - mae: 0.1415 - val_loss: 0.0664 - val_mse: 0.0664 - val_mae: 0.1835
# iter #453
# Batch number: 0
# 79/79 [==============================] - 53s 665ms/step - loss: 0.0363 - mse: 0.0363 - mae: 0.1438 - val_loss: 0.0589 - val_mse: 0.0589 - val_mae: 0.1727
# iter #454
# Batch number: 17
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0360 - mse: 0.0360 - mae: 0.1436 - val_loss: 0.0566 - val_mse: 0.0566 - val_mae: 0.1684
# iter #455
# Batch number: 27
# 79/79 [==============================] - 51s 645ms/step - loss: 0.0364 - mse: 0.0364 - mae: 0.1430 - val_loss: 0.0616 - val_mse: 0.0616 - val_mae: 0.1759
# iter #456
# Batch number: 48
# 79/79 [==============================] - 53s 670ms/step - loss: 0.0371 - mse: 0.0371 - mae: 0.1448 - val_loss: 0.0616 - val_mse: 0.0616 - val_mae: 0.1782
# iter #457
# Batch number: 44
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0354 - mse: 0.0354 - mae: 0.1411 - val_loss: 0.0559 - val_mse: 0.0559 - val_mae: 0.1689
# iter #458
# Batch number: 13
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0391 - mse: 0.0391 - mae: 0.1483 - val_loss: 0.0587 - val_mse: 0.0587 - val_mae: 0.1720
# iter #459
# Batch number: 20
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0347 - mse: 0.0347 - mae: 0.1387 - val_loss: 0.0616 - val_mse: 0.0616 - val_mae: 0.1768
# iter #460
# Batch number: 35
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0366 - mse: 0.0366 - mae: 0.1450 - val_loss: 0.0571 - val_mse: 0.0571 - val_mae: 0.1681
# iter #461
# Batch number: 26
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0350 - mse: 0.0350 - mae: 0.1401 - val_loss: 0.0621 - val_mse: 0.0621 - val_mae: 0.1747
# iter #462
# Batch number: 1
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0343 - mse: 0.0343 - mae: 0.1400 - val_loss: 0.0612 - val_mse: 0.0612 - val_mae: 0.1748
# iter #463
# Batch number: 8
# 79/79 [==============================] - 51s 642ms/step - loss: 0.0353 - mse: 0.0353 - mae: 0.1402 - val_loss: 0.0638 - val_mse: 0.0638 - val_mae: 0.1777
# iter #464
# Batch number: 7
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0363 - mse: 0.0363 - mae: 0.1434 - val_loss: 0.0568 - val_mse: 0.0568 - val_mae: 0.1689
# iter #465
# Batch number: 32
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0367 - mse: 0.0367 - mae: 0.1459 - val_loss: 0.0614 - val_mse: 0.0614 - val_mae: 0.1755
# iter #466
# Batch number: 30
# 79/79 [==============================] - 52s 645ms/step - loss: 0.0376 - mse: 0.0376 - mae: 0.1458 - val_loss: 0.0617 - val_mse: 0.0617 - val_mae: 0.1776
# iter #467
# Batch number: 9
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0386 - mse: 0.0386 - mae: 0.1461 - val_loss: 0.0605 - val_mse: 0.0605 - val_mae: 0.1770
# iter #468
# Batch number: 2
# 79/79 [==============================] - 51s 645ms/step - loss: 0.0373 - mse: 0.0373 - mae: 0.1455 - val_loss: 0.0613 - val_mse: 0.0613 - val_mae: 0.1740
# iter #469
# Batch number: 10
# 79/79 [==============================] - 51s 645ms/step - loss: 0.0383 - mse: 0.0383 - mae: 0.1472 - val_loss: 0.0640 - val_mse: 0.0640 - val_mae: 0.1784
# iter #470
# Batch number: 34
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0360 - mse: 0.0360 - mae: 0.1435 - val_loss: 0.0629 - val_mse: 0.0629 - val_mae: 0.1785
# iter #471
# Batch number: 36
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0390 - mse: 0.0390 - mae: 0.1478 - val_loss: 0.0559 - val_mse: 0.0559 - val_mae: 0.1675
# iter #472
# Batch number: 41
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0389 - mse: 0.0389 - mae: 0.1477 - val_loss: 0.0612 - val_mse: 0.0612 - val_mae: 0.1737
# iter #473
# Batch number: 21
# 79/79 [==============================] - 52s 650ms/step - loss: 0.0367 - mse: 0.0367 - mae: 0.1441 - val_loss: 0.0604 - val_mse: 0.0604 - val_mae: 0.1728
# iter #474
# Batch number: 19
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0355 - mse: 0.0355 - mae: 0.1413 - val_loss: 0.0618 - val_mse: 0.0618 - val_mae: 0.1760
# iter #475
# Batch number: 24
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1476 - val_loss: 0.0571 - val_mse: 0.0571 - val_mae: 0.1732
# iter #476
# Batch number: 15
# 79/79 [==============================] - 52s 658ms/step - loss: 0.0364 - mse: 0.0364 - mae: 0.1442 - val_loss: 0.0595 - val_mse: 0.0595 - val_mae: 0.1763
# iter #477
# Batch number: 18
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0379 - mse: 0.0379 - mae: 0.1468 - val_loss: 0.0610 - val_mse: 0.0610 - val_mae: 0.1738
# iter #478
# Batch number: 28
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0358 - mse: 0.0358 - mae: 0.1424 - val_loss: 0.0572 - val_mse: 0.0572 - val_mae: 0.1706
# iter #479
# Batch number: 16
# 79/79 [==============================] - 51s 645ms/step - loss: 0.0353 - mse: 0.0353 - mae: 0.1411 - val_loss: 0.0589 - val_mse: 0.0589 - val_mae: 0.1721
# iter #480
# Batch number: 45
# 79/79 [==============================] - 51s 645ms/step - loss: 0.0382 - mse: 0.0382 - mae: 0.1454 - val_loss: 0.0616 - val_mse: 0.0616 - val_mae: 0.1763
# iter #481
# Batch number: 46
# 79/79 [==============================] - 52s 650ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1492 - val_loss: 0.0567 - val_mse: 0.0567 - val_mae: 0.1708
# iter #482
# Batch number: 33
# 79/79 [==============================] - 51s 645ms/step - loss: 0.0380 - mse: 0.0380 - mae: 0.1462 - val_loss: 0.0586 - val_mse: 0.0586 - val_mae: 0.1707
# iter #483
# Batch number: 42
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0367 - mse: 0.0367 - mae: 0.1437 - val_loss: 0.0586 - val_mse: 0.0586 - val_mae: 0.1720
# iter #484
# Batch number: 6
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0378 - mse: 0.0378 - mae: 0.1468 - val_loss: 0.0591 - val_mse: 0.0591 - val_mae: 0.1743
# iter #485
# Batch number: 14
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0363 - mse: 0.0363 - mae: 0.1434 - val_loss: 0.0637 - val_mse: 0.0637 - val_mae: 0.1799
# iter #486
# Batch number: 12
# 79/79 [==============================] - 52s 648ms/step - loss: 0.0390 - mse: 0.0390 - mae: 0.1479 - val_loss: 0.0578 - val_mse: 0.0578 - val_mae: 0.1698
# iter #487
# Batch number: 43
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0404 - mse: 0.0404 - mae: 0.1489 - val_loss: 0.0554 - val_mse: 0.0554 - val_mae: 0.1675
# iter #488
# Batch number: 47
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0374 - mse: 0.0374 - mae: 0.1455 - val_loss: 0.0572 - val_mse: 0.0572 - val_mae: 0.1697
# iter #489
# Batch number: 23
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0361 - mse: 0.0361 - mae: 0.1443 - val_loss: 0.0592 - val_mse: 0.0592 - val_mae: 0.1749
# iter #490
# Batch number: 3
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0384 - mse: 0.0384 - mae: 0.1466 - val_loss: 0.0605 - val_mse: 0.0605 - val_mae: 0.1768
# iter #491
# Batch number: 37
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0364 - mse: 0.0364 - mae: 0.1431 - val_loss: 0.0610 - val_mse: 0.0610 - val_mae: 0.1761
# iter #492
# Batch number: 38
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0371 - mse: 0.0371 - mae: 0.1438 - val_loss: 0.0606 - val_mse: 0.0606 - val_mae: 0.1739
# iter #493
# Batch number: 39
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0354 - mse: 0.0354 - mae: 0.1432 - val_loss: 0.0602 - val_mse: 0.0602 - val_mae: 0.1739
# iter #494
# Batch number: 25
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0378 - mse: 0.0378 - mae: 0.1465 - val_loss: 0.0578 - val_mse: 0.0578 - val_mae: 0.1726
# iter #495
# Batch number: 5
# 79/79 [==============================] - 51s 644ms/step - loss: 0.0367 - mse: 0.0367 - mae: 0.1445 - val_loss: 0.0603 - val_mse: 0.0603 - val_mae: 0.1746
# iter #496
# Batch number: 29
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0380 - mse: 0.0380 - mae: 0.1473 - val_loss: 0.0599 - val_mse: 0.0599 - val_mae: 0.1732
# iter #497
# Batch number: 11
# 79/79 [==============================] - 53s 667ms/step - loss: 0.0367 - mse: 0.0367 - mae: 0.1449 - val_loss: 0.0646 - val_mse: 0.0646 - val_mae: 0.1840
# iter #498
# Batch number: 22
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1497 - val_loss: 0.0682 - val_mse: 0.0682 - val_mae: 0.1830
# iter #499
# Batch number: 49
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1470 - val_loss: 0.0592 - val_mse: 0.0592 - val_mae: 0.1756

# %% [markdown]
# ## Plotting the evaluation metrics
#
# The following analysis is constantly performed to monitor the behavior of the network as it trains.

# %%
import pandas as pd

with open(ckpt_dir+"evalDict.json") as json_file:
        evalDict = json.load(json_file)

df =  pd.DataFrame.from_dict(evalDict).T   

df.tail()
# Out:
#           loss        mse       mae   val_loss    val_mse   val_mae batchNo  \
# 495  0.0363477  0.0363477  0.143239  0.0603462  0.0603462  0.174607       5
# 496   0.037682   0.037682  0.146266  0.0599022  0.0599022  0.173195      29
# 497  0.0368696  0.0368696  0.144449     0.0646     0.0646  0.183983      11
# 498  0.0385604  0.0385604  0.147271  0.0682263  0.0682263  0.183042      22
# 499  0.0372543  0.0372543  0.144647  0.0592049  0.0592049  0.175574      49
#
#                     batchFile
# 495  128x128_train_aug_06.npz
# 496  128x128_train_aug_30.npz
# 497  128x128_train_aug_12.npz
# 498  128x128_train_aug_23.npz
# 499  128x128_train_aug_50.npz

# %% [markdown]
# After about 100 iterations, the training and testing metrics detach from each other, meaning the training process not longer produces reliable results.
#
# Note that the results of this network is NOT better than our fully developed CNNs (models 4, 5, and 6).
# In all of those models the ultimate values of RMSE and MAE are better than 0.05 and 0.125 (deg), respectively, while with the current network these metrics are worse than out expectation.
#
# There might be the case that the transferred information from the convolutional layers of VGG16 doesn't perfectly suite our problem. Allowing some of the convolutional layers to be trainable might help with the situation, however the number of trainable parameters would be much bigger in that case that contradicts the purpose of the transfer learning process, which is to reduce the training time with lesser available computational resources.

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(11,5))

epochs = np.arange(len(df))

ax[0].plot(epochs, df.mse.values, label='Training')
ax[0].plot(epochs, df.val_mse, label='Validation', alpha=0.5)
ax[0].set_title('Mean Square Error')
ax[0].legend()
ax[0].set_xlabel('Epoch', fontsize=14)
ax[0].set_ylabel('Loss', fontsize=14)
ax[0].set_ylim(0, 0.3)

ax[1].plot(epochs, df.mae.values, label='Training')
ax[1].plot(epochs, df.val_mae, label='Validation', alpha=0.5)
ax[1].set_title('Mean Absolute Error Curves')
ax[1].legend()
ax[1].set_xlabel('Epoch', fontsize=14)
ax[1].set_ylabel('Mean Absolute Error', fontsize=14)
ax[1].set_ylim(0.1, 0.3)
# Out:
# (0.1, 0.3)

# %% [markdown]
# # Conclusion: the performance of the trained network is no better than our original models
#
# In following cells, we repeat the same process of examining the results. Clearly all performance metrics of the adapter VGG16 are not better than our previous results. However, if one is looking for getting a descent model by avoiding a long training time, this model is a good replacement, although this is not in favor of our project objectives.

# %% [markdown]
# ## Predictions vs. Actual measurements
#
# We cross compare the evaluated inclinations versus the actual labels.
#
# To get better understanding of the model performance, we plot the difference between the evaluated inclinations and the measured values by users ($\Delta i-i_m-i_p$). In the following plot, the horizontal axis shows the measured inclinations. Each point represents a galaxy in the test sample.
#
# - **Left Panel:** Predicted values $i_p$, are directly generated by applying the trained network on the test sample. Red sold line displays the results of a least square linear fit on the blue points. Evidently, there is a inclination dependent bias that is inclination dependent. This bias has been linearly modeled by the red line, which is utilized to adjust the predicted values. The slope and intercept of the fitted line are encoded in the $m$ and $b$ parameters.
# - **Right Panel:** Same as the left panel, with adjusted predictions, $i_{pc}$, that is calculated using $i_{pc}= \frac{i_p+b}{1-m}$.
#
# **Note:** The root mean square of the prediction$-$measurements differences is $~4^o$. The similar metric is $~2.6^o$ when we compare the measured values of two groups of the human users. This means our model is slightly performs worst than human, and most of that poor performances is attributed to the outliers and features (like data noise, point sources, stellar spikes, poor images, etc.) with no enough data coverage.
#
# The performance of the trained network is slightly worse than our prototype ($~3^o$), because augmentation introduces a lot of different possibilities that requires a large sample and many more iterations to achieve the same goal. In the prototype model, we adopted 64x64 images, and all galaxies where aligned horizontally, whereas in the full augmented analysis, galaxies are left to have arbitrary position angles. This adds to the complexity of the problem.

# %%
with tf.device('/gpu:0'):    
    vgg_model = vgg()
    vgg_model.load_weights(ckpt_dir+"499.ckpt")

    inc_p = vgg_model.predict(images_test_aug)
    inc_m = 0.5*(labels_test_aug+1.)*45.+45.

    N = images_test_aug.shape[0]
    inc_p = inc_p.reshape(N)
    inc_p = 0.5*(inc_p+1.)*45.+45.


    fig, ax = plt.subplots(nrows=1,ncols=2, figsize=(10,5)) 
    
    
    d = inc_m-inc_p
    
    ix = ((d<12)&(d>-12))

    m, b = np.polyfit(inc_m[ix], d[ix], 1)
    x = np.linspace(50,90,20)
    y  = m*x+b

    ax[0].plot(inc_m, d, 'b.', alpha=0.5)
    ax[0].plot([50,90],[0,0], 'k:')
    ax[0].plot(x, y, 'r-')
    ax[0].set_xlim(48,92)
    ax[0].set_ylim(-30 ,30)
    ax[0].set_title('Raw Prediction', fontsize=16)
    ax[0].set_xlabel(r'$i_m$'+'  (measured inclination)', fontsize=14)
    ax[0].set_ylabel(r'$\Delta i = i_m-i_p$', fontsize=14)

    print("Raw RMS: ", np.sqrt(np.mean((d)**2)))

    inc_p2 = (inc_p+b)/(1.-m)
#     inc_p2[(inc_p2>90)] = 90

    d_ = inc_m-inc_p2
    ax[1].plot(inc_m, d_, 'g.')
    ax[1].plot([50,90],[0,0], 'k:')
    ax[1].set_xlim(48,92)
    ax[1].set_ylim(-30,30)

    print("Adjusted RMS: ", np.sqrt(np.mean((d_)**2)))
    ax[1].set_title('Adjusted Prediction', fontsize=16)
    ax[1].set_xlabel(r'$i_m$'+'  (measured inclination)', fontsize=14)
    ax[1].set_ylabel(r'$\Delta i = i_m-i_{pc}$', fontsize=14)

    plt.subplots_adjust( wspace=0.3)
# Out:
# Raw RMS:  5.4747152888942825
# Adjusted RMS:  5.752512285945591

# %% [markdown]
# ## Visualizing the outliers
#
# Here, we show the first 49 galaxy images in the test sample, where the predicted value is far from the actual measurements, i.e. $\Delta i > 10^o$.
#
# In each panel, cyan label is the galaxy ID in the Principal Galaxy Catalog (PGC), and green and red labels represent the measured and the predicted inclinations. Magenta labels denote the panel numbers.
#
# Some cases are interesting:
#
# 1. In panel #42, the galaxy image has been masked out because of the bright center of the galaxy has saturated the image at the center.
# 2. Case #26 is a typical case, where the galaxy image has been projected next to a bright star.
# 3. Cases like #2, #14, #23, #29, #43 have poor quality images.
# 4. Case #37 has been ruined in the data reduction process, when the telescope data has been preprocessed.

# %%
n = 7
m = 7

fig, axes = plt.subplots(nrows=n, ncols=m, figsize=(15,15)) 

t = 0 
ii = 1
delta = np.abs(inc_m[t]-inc_p[t])
for i in range(n):
    for j in range(m):
        
        while t<len(inc_m) and delta < 10:
          t += 1
          delta = np.abs(inc_m[t]-inc_p[t])
        ax = axes[i][j]
        ax.imshow(images_test_aug[t,:,:])

        plt.setp(ax.get_xticklabels(), visible=False)
        plt.setp(ax.get_yticklabels(), visible=False)

        ax.text(30, 200, "%.0f"%inc_m[t], color='green', fontsize=12)
        ax.text(180, 30, ii, color='magenta', fontsize=12); ii+=1
        ax.text(180, 200, "%.0f"%inc_p[t], color='red', fontsize=12)
        ax.text(30, 30, pgcIDs_test_aug[t], color='cyan', fontsize=12)

        t+=1
        delta = np.abs(inc_m[t]-inc_p[t])

plt.subplots_adjust(hspace=0.03, wspace=0.03)

# %% [markdown]
# # Summary
#
# We adopted the convolutional layers of the VGG16 that has been trained using the [ImageNet](https://www.image-net.org/) dataset. We kept the convolutional layers unchanged by setting their trainablity attribute to `false`. Removing the last fully connected layers, we introduced our customized fully connected layers. We trained the fully connected part to fit our sample galaxies. It turned out that the new structure is trainable to some extent, however its performance is not better than our original network designs. We suggest to allow a couple of the convolutional layers to be readjusted in order to get better fits, however this might not be the case in the end, according to the number of additional weights that need to be trained, as well as the small size of our training sample. We can improve the training sample size by adding more augmentations, however this increases the training time and requires us to leverage more computational resources that is not justifiable while our original models are cheaper to train and much simpler and produce more precise predictions.
